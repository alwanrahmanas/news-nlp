# %%
import pandas as pd

# %%
df = pd.read_excel(r"C:\Users\US3R\OneDrive\Dokumen\data-science\Project\sumateranomics\nlp\nlp_pipeline_v2\data\validation\sample_200_for_annotation.xlsx")

# %%
df
# Out:
#            article_id published_date              source  \
# 0    b37237ffccaaab54     2025-02-25     aktualdetik.com
# 1    70a6f903fbcc95ec     2026-02-19       hariansib.com
# 2    f1a8f4108172a871     2021-05-11      antaranews.com
# 3    1993917555a7970c     2023-06-27           detik.com
# 4    837d569d9ffde3a8     2026-02-13  bidikkasusnews.com
# ..                ...            ...                 ...
# 195  65f933923c9d2b13     2025-10-07           detik.com
# 196  c81bf84b9a200afc     2025-11-28  sumut.idntimes.com
# 197  4db7fa37ff48cb78     2023-01-18      antaranews.com
# 198  7eb757662c44a737     2024-06-25           detik.com
# 199  aba4955af97530d8     2026-02-01    cnnindonesia.com
#
#                                                  title  \
# 0    Satgas Pangan Polres Belawan Dan Dinas Ketahan...
# 1    Usai Lonjakan Awal Ramadan, Belanja Warga Meda...
# 2                                                  NaN
# ...

# %%
df2 = pd.read_parquet(r"data\processed\extractions_clean.parquet")
df2
# Out:
#            article_id                                                url  \
# 0    e225a922e1b8da79  https://www.antaranews.com/berita/5444418/bapa...
# 1    7a09e533e5974c64  https://www.antaranews.com/berita/5442698/mend...
# 2    ef930442caf83b96  https://www.antaranews.com/berita/5441730/ment...
# 3    c18a52a4aafa97d2  https://www.antaranews.com/berita/5439938/satg...
# 4    5854f467d51b5b34  https://www.antaranews.com/berita/5431362/bapa...
# ..                ...                                                ...
# 770  388feee9b54e12a6    https://rri.co.id/medan/bisnis/1270880/faq.html
# 771  4d55a39ddb100ce9  https://rri.co.id/ramadan/619820/satgas-pangan...
# 772  97cc78f03679d6ab  https://www.kompas.id/artikel/kppu-sumut-cerma...
# 773  cfb7fc9db4fd1d70  https://rri.co.id/daerah/549280/pemprov-riau-k...
# 774  ceb46f96b176b089  https://www.riau1.com/berita/riau/tak-sanggup-...
#
#              source                                              title  \
# ...

# %%
df2 = df2.sort_values(by='published_date', ascending=True)

# %%
df2['full_text'].iloc[0]
# Out:
# 'pengoperasian mesin CAS untuk menyimpan pasokan cabai dan bawang masih membutuhkan biaya tinggi.\nJakarta (ANTARA) - Dinas Ketahanan Pangan, Kelautan dan Pertanian (DKPKP) DKI Jakarta berkoordinasi dengan Perusahaan Daerah (Perumda) Pasar Jaya akan menggunakan mesin penyimpan atau \'Controlled Atmosphere Storage\' (CAS) untuk mengendalikan harga cabai merah di Ibu Kota.\n"Perumda Pasar Jaya punya mesin CAS, tahun 2021 ini kita optimalkan penggunaannya, supaya kenaikan harga cabai tidak berulang setiap tahun," kata Pelaksana tugas (Plt) Kepala DKPKP DKI Jakarta, Suharini Eliawati, saat dikonfirmasi di Jakarta, Jumat.\nBaca juga: DKPKP DKI siapkan operasi pasar tekan harga cabai\nElly, sapaan akrab Eliawati menyebutkan, mesin CAS yang ada di sejumlah pasar di bawah pengelolaan Perumda Jaya diisi dengan cabai rawit dan bawang merah.\nMesin CAS mampu menyimpan cabai rawit dan bawang merah dengan umur simpan hingga lima bulan.\n"Tidak semua jenis cabai yang bisa disimpan di mesin CAS. Ha
# ...

# %%
df2
# Out:
#            article_id                                                url  \
# 160  6f4c407f73947a9a  https://www.antaranews.com/berita/1974342/dkpk...
# 470  6807664a252a9194  https://news.detik.com/berita/d-5482810/kisruh...
# 434  31dd0680d2325c21  https://finance.detik.com/berita-ekonomi-bisni...
# 133  d3adee390f441766  https://www.antaranews.com/berita/2104866/bi-p...
# 115  2232214d2aaabe8e  https://www.antaranews.com/berita/2133070/ment...
# ..                ...                                                ...
# 559  6445b1b4ed465cd1  https://sumsel.idntimes.com/news/sumatra-selat...
# 556  d93dd25ce263150f  https://rri.co.id/meulaboh/ramadan/2224685/per...
# 552  b71c3891ec8b4ece  https://rri.co.id/aceh-singkil/ekonomi/bisnis/...
# 629  4543a81e1b221690  https://sumut.indozone.id/news/2486671450/wagu...
# 0    e225a922e1b8da79  https://www.antaranews.com/berita/5444418/bapa...
#
#                   source                                              title  \
# ...

# %%
df2[df2['published_date']=='2026-02-03']
# Out:
#            article_id                                                url  \
# 189  dfb732872c264351  https://www.detik.com/bali/nusra/d-8338673/har...
# 188  e9420c3fa45346c2  https://www.detik.com/sumut/berita/d-8339307/h...
# 707  65d7537b96e627ac  https://rri.co.id/medan/keuangan/2156038/sumut...
# 744  203694cc49fc38f8  https://bisnisjakarta.co.id/inflasi-pangan-mel...
# 218  f7fc84b124085e7b  https://www.detik.com/sumbagsel/berita/d-83375...
# 190  d29296a0fbbf2b43  https://www.detik.com/sumbagsel/berita/d-83364...
# 688  b942a77e70b2ac3a  https://mediaindonesia.com/nusantara/856600/kr...
#
#                   source                                              title  \
# 189            detik.com
# 188            detik.com
# 707            rri.co.id  Sumut Deflasi Januari, Waspada Inflasi Februar...
# 744  bisnisjakarta.co.id  Inflasi Pangan Melandai Jadi Bukti Stabilitas ...
# 218            detik.com
# 190            detik.com
# ...
